# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle
import numpy as np
from IPython.display import display
import re

# %%
planilha1=pd.read_excel("era uma vez em hollywood.xlsx", sheet_name='Teste')

# %%
excelcomrt=planilha1.set_index('Teste')

# %%
excel1=excelcomrt.loc[excelcomrt['Classificação']!=3]

# %%
planilha2=pd.read_excel("era uma vez em hollywood2.xlsx", sheet_name='Teste')

# %%
excel2=planilha2.set_index('Teste')

# %%
tabela = excel1.append(excel2)
tabela
# Out:
#                                                    Classificação
# Teste
# finalmente indo assistir era uma vez em hollywo...             0
# era uma vez em hollywood é muito foda, puta que...             1
# vi na @cinesala o novo trabalho de quentin tara...             1
# assisti era uma vez em hollywood e, honestament...             2
# a trilha de era uma vez em hollywood é muito bo...             1
# o final de era uma vez em hollywood é mt bom, m...             1
# depois de bacurau assistam era uma vez em holly...             0
# vamo no cinema hj? — vou hj as 15h assistir era...             0
# o meu é:\n\n1) à prova de morte\n2) pulp fictio...             0
# era uma vez em hollywood é um filmaço do caralho               1
# era uma vez em hollywood premiere em #cannes \n...             0
# @fernandokba @otakuatleta eu vou cedo e c mais ...             0
# @gianne_oliveira era uma vez em hollywood!! g-e...             1
# ...
