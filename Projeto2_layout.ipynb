# %% [markdown]
# # Projeto 2 - Ciência dos Dados

# %% [markdown]
# Nome: _____
#
# Nome: _____

# %% [markdown]
# Serão permitidos grupos de três pessoas, mas com uma rubrica mais exigente. Grupos deste tamanho precisarão fazer um questionário de avaliação de trabalho em equipe

# %% [markdown]
# ___
# # Classificador automático de sentimento

# %% [markdown]
# ## Preparando o ambiente no jupyter:

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle
import numpy as np
from IPython.display import display
import re

# %% [markdown]
# ___
# ## Autenticando no  Twitter
#
# * Conta: ***[Preencha aqui o id da sua conta. Ex: @fulano ]***

# %%
#Dados de autenticação do twitter:

#Coloque aqui o identificador da conta no twitter: @datasci55696539

#leitura do arquivo no formato JSON
with open('auth.pass') as fp:    
    data = json.load(fp)

#Configurando a biblioteca. Não modificar
auth = tweepy.OAuthHandler(data['consumer_key'], data['consumer_secret'])
auth.set_access_token(data['access_token'], data['access_token_secret'])

# %% [markdown]
# ___
# ## Etapas do projeto:

# %% [markdown]
# ### Escolha de um produto e coleta das mensagens

# %%
#Produto escolhido:
produto = 'era uma vez em hollywood -filter:retweets'

#Quantidade mínima de mensagens capturadas:
n = 750
#Quantidade mínima de mensagens para a base de treinamento:
t = 300

#Filtro de língua, escolha uma na tabela ISO 639-1.
lang = 'pt'

# %% [markdown]
# Capturando os dados do twitter:

# %%
#Cria um objeto para a captura
api = tweepy.API(auth)

#Inicia a captura, para mais detalhes: ver a documentação do tweepy
i = 1
msgs = []
for msg in tweepy.Cursor(api.search, q=produto, lang=lang, tweet_mode="extended").items():    
    if not msg.retweeted:
        msgs.append(msg.full_text.lower())
    i += 1
    if i > n:
        break

#Embaralhando as mensagens para reduzir um possível viés
shuffle(msgs)
# Out:
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-11-93a650b27322> in <module>
#       5 i = 1
#       6 msgs = []
# ----> 7 for msg in tweepy.Cursor(api.search, q=produto, lang=lang, tweet_mode="extended").items():
#       8     if not msg.retweeted:
#       9         msgs.append(msg.full_text.lower())
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     231                     raise RateLimitError(error_msg, resp)
#     232                 else:
# --> 233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     234
#     235             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %%
import re 

def cleanup(text):
    punctuation = '[!\-.:?;]'
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, ' ', text)
    return text_subbed

# %%
nariz = cleanup(msgs.lower())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d44a17e2cdec> in <module>
# ----> 1 nariz = cleanup(msgs.lower())
#
# AttributeError: 'list' object has no attribute 'lower'

# %% [markdown]
# Salvando os dados em uma planilha Excel:

# %%
#Verifica se o arquivo não existe para não substituir um conjunto pronto
if not os.path.isfile('./{0}.xlsx'.format(produto)):
    
    #Abre o arquivo para escrita
    writer = pd.ExcelWriter('{0}.xlsx'.format(produto))

    #divide o conjunto de mensagens em duas planilhas
    dft = pd.DataFrame({'Treinamento' : pd.Series(msgs[:t])})
    dft.to_excel(excel_writer = writer, sheet_name = 'Treinamento', index = False)

    dfc = pd.DataFrame({'Teste' : pd.Series(msgs[t:])})
    dfc.to_excel(excel_writer = writer, sheet_name = 'Teste', index = False)

    #fecha o arquivo
    writer.save()

# %% [markdown]
# ___
# ### Classificando as mensagens na coragem
#
# Esta etapa é manual. Faça a mesma pelo Excel.

# %%
def cleanup(text):
    punctuation = '[!\"-.:?;,\n]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    text_subbed = re.sub(pattern, ' ', text)
    return text_subbed

# %%
#filme = open("era uma vez em hollywood.xlsx", "r", encoding="utf8")
excel=pd.read_excel("era uma vez em hollywood.xlsx", sheet_name='Teste')

# %%
msgs
# Out:
# ['rt @olhardigital: brad pitt confirmou, ao indiewire, que quentin tarantino pretende mesmo fazer uma versão estendida de era uma vez em holl…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'o tal charlie dos hippies (menção) do era uma vez em hollywood era o charles manson???',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  "ansioso pra saber do meu palestrinha @eltonpeixe o que ele achou do filme 'era uma vez em hollywood' do tarantino",
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'assisti "era uma vez em hollywood" e só digo uma coisa: tarantino tá começando a ficar superestimado. bjos e boa noite...',
#  'acabei de ver o era uma vez em hollywood e sei lá',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'fica aí a dica “era uma vez em hollywood”',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  '@imwhiteflag @martinthebilly @vicebrasil era uma vez em hollywood é o meu filme favorito do tarantino, eu considero o filme uma grande homenagem a antiga hollywood e sharon tate mas é claro que não é a melhor obra dele.\n\nmas dizer que é a pior filme dele é um ultraje.',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'porra eu morri de rir na cena do bruce lee, que isso aqueles gritinhos são os melhores kkkkkkk\nera uma vez em hollywood é o melhor filme ♥️',
#  'preciso encontrar um streamming bom pra assistir era uma vez em hollywood',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'era uma vez em hollywood vai virar série https://t.co/bw0r7bhepw',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'bacurau bota era uma vez em hollywood pra mamaaaaarrrrr',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @castrofbpa_: pelas próximas duas quartas vou precisar ir no cinema 21h30\n\npelo menos tem era uma vez em hollywood e it 2 em cartaz',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  '@kmendoncafilho @alexluizbr o cinema é lindo, oq estraga é cinéfilo caga-regra e treteiro. o meu coração tem espaço de sobra pra bacurau e era uma vez em... hollywood',
#  '@gbfelipe7 irmão, falo com propriedade: bacurau é muito mais redondo que o era uma vez em hollywood.\nmas são dois filmes sinistros.',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @mikhaetc: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿…',
#  'eu queria assistir todos os filmes que estão em cartaz mas provavelmente só vou conseguir o era uma vez em hollywood (que já assisti) e it 2 \n\nisso porque são títulos famosos e fiz a lista no começo do ano',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'bacurau ainda estou raciocinando tudo, muito maravilhoso e era uma vez em hollywood só digo uma coisa: obra-prima!\ndicaprio e pitt em suas melhores atuações... depois falo mais detalhes.',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  '@louisliberte era uma vez em hollywood é uma bosta',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'era uma vez em hollywood é horrível https://t.co/huigbop6fo',
#  'charles manson é meu novo signo.\nsó pode\namerican horros story cult depois mindhunter e agora era uma vez em hollywood e depois no #imaginajuntas  \neu não aguento mais tanto charles manson',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'saiu a programação semanal do circuito @spcine_ até 18/9, com destaques para a sessão especial de "taxi driver", para a estreia de "era uma vez em... hollywood" e para mostra taturana de cinema pela democracia. acesse: https://t.co/47fidgbcsl https://t.co/qcn5lhurb0',
#  'ai queria ser só tipo a hippie bonitinha de era uma vez em hollywood',
#  'assisti "era uma vez em hollywood" e é o pior filme do tarantino que já vi.',
#  '@piclesderretido era uma vez em hollywood',
#  'brad pitt confirmou, ao indiewire, que quentin tarantino pretende mesmo fazer uma versão estendida de era uma vez em hollywood, seu longa mais recente\n\nhttps://t.co/uf3fhaizyq',
#  'era uma vez em hollywood um filme bem arrastado q eu quase dormir em umas partes do filme',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'a geração "nescau vs toddy", "frio vs calor", "marvel vs dc", quis iniciar o motim "bacurau vs era uma vez em hollywood", mas se fuderam https://t.co/murikqlcqh',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'faz um mês que eu vi era uma vez em hollywood e ainda não parei de escutar a trilha sonora desse filme',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  '@totailynotme era uma vez em hollywood é legal, mas bacurau ta em outro nivel',
#  'putz, agora chegou era uma vez em hollywood no cinema q eu vou, mas só vou poder assistir pra lá de outubro, já era',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @carlinhosmofio: checklist dos próximos filmes que quero assistir: \n\n- it \n- brinquedo assassino\n- hebe a estrela do brasil\n- coringa \n-…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'era uma vez em hollywood, o nono filme de #tarantino. o título explica o final surpreendente (pelo menos pra mim)',
#  'e no cinema do dragão que dá é pra assistir no mesmo dia bacurau, era uma vez em hollywood e ainda acabar com a besteira https://t.co/zxhspeqkos',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @mikhaetc: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  '@vihhlee @rafaello1313 o cara fala que não é bom, porque é só mais um trouxa que não estudou a história, e nem captou a chuva de referências da época, que o diretor colocou em era uma vez em hollywood. sem falar nos recordes de bilheteria e críticas positivas de quem, de fato, entende.',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'era uma vez em hollywood demorou pra me conquistar mas quando foi meu deus que filmaço',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @cinema505: realidade: era uma vez em... hollywood surrado por bacurau em cannes. https://t.co/y4jgpswkbg',
#  'não aguento mais a joyce falando mal de era uma vez em hollywood vou perder as estribeiras com essa cinéfila 😡😡😡😡',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @ohnanax: vcs já conseguiram entender que bacurau faturou mais que era uma vez em hollywood esse fim de semana? vá assistir bacurau cara…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  "a primeira coisa a se dizer sobre 'era uma vez... em hollywood' é q o filme faz uma grande auto referência a tudo q o quentão gosta: filme de western, nazista pegando fogo, fetiche com pé (chega a ser um deboche do tanto que ele abusa desse recurso), diálogos triviais e violência",
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'na boa, não estou entendendo essa briguinha atoa, essa competição ridícula entre bacural e era uma vez em... hollywood. há menos de um mês tarantino ainda era herói descolados, daí do nada o cara virou chacota para os mesmo descolados. essa “lacração” tá passando dos limites. https://t.co/ffzwp9xmsu',
#  'kkkkkkkkkkkkkkk bacurau eh 500 vzs melhor do que era uma vez em hollywood. pode ser dirigido peli papa https://t.co/wp6ohb256n',
#  'impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau                era uma vez\n                                em hollywood https://t.co/n1bhfabbl3',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'assisti era uma vez em hollywood ontem.. eu achava que não podia ser mais otária pela margot mas pqp cada hora que a mulher aparecia no filme eu ficava sorrindo que nem uma idiota @margotrobbie o que você fez comigo?',
#  'ainda não entendi porque não pode gostar de “era uma vez em hollywood” e “bacurau” ao mesmo tempo. é alguma regra implícita no reino dos cinéfilos ou é só encheção de saco mesmo?',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  

#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'na semana que saiu era um vez em hollywood eu fui comentar com uma amiga que queria ver, ela não fazia a mínima ideia de quem era e depois eu fui checar e descobrir que ninguém na minha sala conhecia ele',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @glimmerwho: bacurau fez o que era uma vez em hollywood não conseguiu fazer\n\nboa noite',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @mikhaetc: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  '@isthiskarol @elaapropria os únicos que ainda n vi foram: à prova de morte, grande hotel e era uma vez em... hollywood.',
#  'rt @leon_sem_ardo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  '@kmendoncafilho era uma vez em hollywood é uma merda kkk só faz sucesso pq é americano e feito por um branco de hollywood.\n\npra não ser injusto, os último 15min do filme são engraçados. mas porra, 3 hrs pra 15 min valerem a pena ? meu tempo de vida vale mais https://t.co/ijgizht1ca',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'gostei de era uma vez em hollywood. a cena final é espetacular, de verdade. que fantasia.\n\nagora assistiremos bacurau.\n\nsim, dá para assistir e gostar dos dois.\né que eu gosto de filme, de cinema, sabe?',
#  'rt @paredesmesmo: impacto cultural:\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █…',
#  'rt @vicebrasil: .\n\n         █          \u3000\u3000\n         █\u3000        \n         █\u3000        \n         █\u3000                           ＿\n   bacurau…',
#  'rt @donabbade: bacurau arrecadou mais dinheiro que era uma vez em hollywood nesse último fim de semana (mesmo estando em cartaz em menos sa…',
#  'era uma vez em hollywood é o melhor filme que assisti até agora (ta pra sair the irishman, scorcese)']

# %%
ids = set()
for tweet in tweepy.Cursor(api.search, 
                    q="docker", 
                    Since="2016-08-09", 
                    #until="2014-02-15", 
                    lang="en").items(5000000):
if not tweet['retweeted'] and 'RT @' not in tweet['text']:
    #Write a row to the csv file/ I use encode utf-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8'), tweet.favorite_count, tweet.retweet_count, tweet.id, tweet.user.screen_name])
    #print "...%s tweets downloaded so far" % (len(tweet.id))
    ids.add(tweet.id) # add new id
    print ("number of unique ids seen so far: {}",format(len(ids)))
csvFile.close()

# %% [markdown]
# ___
# ### Montando o Classificador Naive-Bayes
#
# Considerando apenas as mensagens da planilha Treinamento, ensine  seu classificador.

# %%
serie_filme = pd.Series(excel.split())

# %% [markdown]
# ___
# ### Verificando a performance
#
# Agora você deve testar o seu classificador com a base de Testes.

# %% [markdown]
# ___
# ### Concluindo

# %% [markdown]
# ## Aperfeiçoamento:
#
# Os trabalhos vão evoluir em conceito dependendo da quantidade de itens avançados:
#
# * Limpar: \n, :, ", ', (, ), etc SEM remover emojis
# * Corrigir separação de espaços entre palavras e emojis ou emojis e emojis
# * Propor outras limpezas e transformações que não afetem a qualidade da informação ou classificação
# * Criar categorias intermediárias de relevância baseadas na probabilidade: ex.: muito relevante, relevante, neutro, irrelevante, muito irrelevante (3 categorias: C, mais categorias conta para B)
# * Explicar por que não posso usar o próprio classificador para gerar mais amostras de treinamento
# * Propor diferentes cenários para Naïve Bayes fora do contexto do projeto
# * Sugerir e explicar melhorias reais com indicações concretas de como implementar (indicar como fazer e indicar material de pesquisa)
# * Montar um dashboard que periodicamente realiza análise de sentimento e visualiza estes dados

# %% [markdown]
# # Referências

# %% [markdown]
# [Naive Bayes and Text Classification](https://arxiv.org/pdf/1410.5329.pdf)  **Mais completo**
#
# [A practical explanation of a Naive Bayes Classifier](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/) **Mais simples**
