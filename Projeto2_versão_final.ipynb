# %% [markdown]
# # Projeto 2 - Classificador Automático de Sentimento

# %% [markdown]
# **Nome:** Beatriz R. Bernardino. <br>
# **Nome:** Vitor I. B. Bandeira.

# %%
# %%capture

#Instalando o tweepy
# !pip install tweepy

# %%
import tweepy
import math
import os.path
import pandas as pd
import json
from random import shuffle
import numpy as np
from IPython.display import display
import re

# %%
planilha1=pd.read_excel("era uma vez em hollywood.xlsx", sheet_name='Treinamento')
#Retirando os rt das planilhas
excel1=planilha1.loc[planilha1['Classificação']!=3]

planilha2=pd.read_excel("era uma vez em hollywood2.xlsx", sheet_name='Treinamento')
#Jutando as planilhas para analise dos dados
tabela = excel1.append(planilha2)

# %%
#Funçaõ para CleanUp dos caracteres indesejados 
def cleanup(text):
    novoindex=[]
    punctuation = '[!\" \n-.:?;,@]' # Note que os sinais [] são delimitadores de um conjunto.
    pattern = re.compile(punctuation)
    for frase in text:
         novoindex.append(re.sub(pattern, ' ', frase))
    return novoindex

# %%
#Aplicando a função CleanUp na nossa planilha analisada
tabela_limpa=cleanup(tabela.Treinamento)
#Ajustando tabela para análise dos dados
tabela_correta=tabela.drop(columns="Treinamento")
tabela_correta['tweets']=tabela_limpa
tabela_limpa
# Out:
# [' frckribery recebi hoje e só lembrei de certas pessoas vendo era uma vez em hollywood  ou melhor  perdendo',
#  'que no caso são  bacurau  era uma vez em hollywood  it capítulo 2  brinquedo assassino  aquele trash de lei   e yesterday  mas não sei se conseguirei ver tudo  tá tudo bem também ',
#  ' eduu_miranda era uma vez gore em hollywood',
#  'eu quero muito assistir bacurau e era uma vez em hollywood mas ai cara pq cinema tem que ser tão caro    ',
#  'vai sair uma versão de 4 horas de era uma vez    em hollywood  e meudeus eu precisook',
#  'bacurau dá de 10 x 0 em era uma vez em hollywood   achei o filme do tarantino meio decepcionante ',
#  'quanto mais leio/ouço sobre  era uma vez em    hollywood  mais eu fico revoltado com a necessidade de background que o filme tem',
#  'boa noite seguidores  hoje a crítica vai para o filme era uma vez    em hollywood  nota 7 5',
#  ' era uma vez em hollywood  ultrapassa a marca dos us  300 milhões mundialmente   https //t co/e6tivo9bav https //t co/vygrqzl6cs',
#  'dá rt se hoje você   tá feliz tá animado tá ansioso tá sorridente tá indo ver era uma vez em hollywood no cinema https //t co/uzbi5kznc3',
#  'a fila tá enorme  esquece  vou ver era uma vez em hollywood https //t co/cqxj5s51xm',
#  'nao ta passando mais bacurau nao ta passando mais era uma vez em hollywood nao ta passando mais yesterday  mas ainda ta passando aquela merda daquele filme do edir filha da puta macêdo',
#  'eu só queria registrar que vi era uma vez em hollywood e tô impactada demais irmãozinho',
#  'ontem eu descobri assistindo era uma vez     em hollywood que eu sou a cachorra do brad pitt',
#  'quase dormi assistindo era uma vez em hollywood',
#  'bixo  faz uns 6 meses que não vou no cinema po  hoje eu acordei muito triste por conta disso  não vi turma da mônica  nem toy story  de homeme aranha  nem pets 2  e pelo jeito que a coisa vai  não vou conseguir ver it2  era uma vez em hollywood e nem bacurau  a diretora aq chora ',
#  'quem eh que vamo assisti bacurau e it  se era uma vez em hollywood ainda ainda tiver em cartaz ele também',
#  ' luide  helioflores  pedrosazevedo era uma vez em hollywood faz uma referência direta a bastardos inglórios e vocês falaram que não  ponto negativo pro podcast',
#  'era só uma companhia pra assistir era uma vez em hollywood',
#  'era uma vez em hollywood é muito bom gente pra quem for assistir  tem que pesquisar sobre sharon tate e charles manson senão não entende direito o filme',
#  'assisti  era uma vez em hollywood    e ainda estou sem palavras  ninguém constrói uma história múltipla com tantas nuances com tarantino ',
#  'it  a coisa   cap 2 bacurau era uma vez em hollywood chucky  tenho esses filmes pra ver  mas não vou conseguir ver todos  nem o  primepasscinema vai me salvar dessa vez',
#  'era uma vez em    hollywood é um puta filme do caralho   ',
#  ' josiasteofilo não consegui assistir o era uma vez em hollywood todo  sai da do cinema antes de terminar  o filme é péssimo  assista outro  confie em mim ',
#  'quem vai comigo no cinema ver era uma vez em hollywood',
#  'well  well  agora part 2 do dia no cinema  assistir era uma vez em hollywood  sozinho na sala de cinema  again   pode vir  margotrobbie',
#  'era uma vez em hollywood = dahora cena final simplesmente épica',
#  'eu preciso assistir era uma vez em hollywood ou it  quero companhias',
#  ' chibnetti e eu q tenho q emendar era uma vez em hollywood   yesterday   it   coringa',
#  ' reachsaravah é mais violento que “era uma vez em hollywood “   faleiesaicorrendo',
#  'nem vi a derrota do gremio  fui ver  era uma vez em hollywood ',
#  'era uma vez em hollywood  it 2 e yesterday  três filmes pra ver  só falta tempo ',
#  ' principedolacre vi não  nem vou ver então  melhor ir ver bacurau ou era uma vez em hollywood msm',
#  'q historia eh essa q era uma vez em hollywood vai virar serie',
#  'interessante que quanto mais eu reflito sobre era uma vez em    hollywood  mais eu amo esse filme  cara  eu sempre fico fascinado com filmes que eu carrego além da tela ',
#  'louca é pouco para assistir era uma vez em hollywood',
#  'quem vai cmg hj assistir era uma vez em hollywood em',
#  'acho que vou assistir “yesterday” hoje  ou “era uma vez em hollywood”  depende dos horários ',
#  ' surtemprala 🤦🏼\u200d♀️ meu deus  só um dos melhores diretores q existe  era uma vez em hollywood  kill bill  django livre  um drink no inferno    etc etc',
#  'no site   era uma vez em hollywood pode ganhar série de tarantino  publicado em cinema sim   https //t co/luotfk23ha por tiago zabinne https //t co/jwpdcpyztw',
#  'assisti  era uma vez rm hollywood  e você percebe o exato momento em que o tarantino chega no set e diz  eu sou o diretor  ',
#  'o personagem do brad pitt em era uma vez em hollywood é uma puta crítica do tarantino  e eu não vejo ngm comentando isso',
#  'filmes que perdi/estou perdendo por falta de tempo para ir ao cinema  dor e glória  rafiki  primos  it 2  era uma vez    em hollywood  o homem que matou dom quixote 😭😭😭  pelo menos  bacurau eu consegui ver  e recomendo ',
#  'eu reclamei que não tinha entrado era uma vez em hollywood no cinema aqui em chapecó  daí entrou em cartaz e eu não conseguir ir ver final de semana  prometo que se não sair de cartaz amanhã eu vou ver',
#  'quentin tarantino discutiu uma minissérie de  era uma vez em hollywood   diz brad pitt marcos gracioli  https //t co/v4zh7436b5 https //t co/bwsqo2yda9',
#  'dos indicados à palma de ouro no último festival de cannes  minha ordem tá   bacurau  https //t co/ofknqyyibc   gt  parasita  https //t co/zgoi5g1ngr   gt  gt  gt  gt  gt  gt  gt  gt  gt  gt  os mortos não morrem  gt  dor  amp  glória  https //t co/gkiirijgqf   gt  era uma vez em hollywood  https //t co/rcvvfoeyks  ',
#  'top 10  bilheteria sabado 07 de setembro  1  it capitulo dois  2  nada a perder 2 3  o rei leão 4  yesterday 5  corgi  top dog 6  bacurau 7  era uma vez em   hollywood 8  velozesfuriosos hobbs  amp  shaw 9  o amor dá trabalho 10  brinquedo assassino',
#  'se eu não assistir era uma vez em hollywood hoje infelizmente terei que cometer uma atrocidade contra arthur e vitória',
#  ' tudo já foi inventado  parece que sim  ao menos na meca do cinema  meia dúzia de tramas resumem todos os filmes  de ‘cidadão kane’ a ‘era uma vez    em hollywood’  https //t co/wzwqys9ofd',
#  ' leonthomasburke era uma vez em hollywood é foda',
#  'tava ouvindo o rapaduracast sobre era uma vez em hollywood  e  jurandirfilho a cena com o bruce lee é uma puta homenagem  ele brincou com o cara  é igual uma imitação satírica  que na verdade é uma homenagem  bobeira problematizarem isso  achei irado ',
#  'to indo ver era uma vez em    hollywood no dragão  ultima vez  no infiltrado na klan tive que sentar no chão  se rolar hoje de novo      gt _ gt ',
#  'depois q esse danado desse torneio acabar  tenho que ir ver bacurau e era uma vez em hollywood',
#  'tava no cinema  no meio do filme entra um cara  alguém 1  e berra   alguém 1  que filme é esse   alguém 2  era uma vez em hollywood   alguém 1  ata  coisas simples  sabe ',
#  'e gostei que em era uma vez em hollywood tem referência ao melhor filme do tarantino e meu preferido dele que é death proof https //t co/5cnc2yopsw',
#  'eu não sabia que tinha personagens que existiram na vida real no filme era uma vez em hollywood  e agora que eu fiquei sabendo da história real  eu fiquei boquiaberto com o assassinato que rolou ',
#  'quem vai assistir era uma vez em hollywood comigo👺',
#  ' lolaescreva lola já assistiu era uma vez em hollywood    tem a seita do manson e trata de um dos maiores crimes cometidos por eles',
#  'em entrevista a nyt  brad pitt confirmou projeto de série de quentin tarantino  baseado no longa  era uma vez em    hollywood   o diretor quer um seriado de faroeste inspirado no personagem de leonardo dicaprio  rick dalton   https //t co/ui0zelgikn',
#  ' aaugustiado fui ver o era uma vez em hollywood pela segunda vez  gostei mto mais vendo pela segunda que pela primeira  sobre it 2  passo',
#  'já viu era uma vez em hollywood  — infelizmente nao to sem dinheiro p ir no cinema https //t co/f6oxftswd5',
#  'ai eu achei era uma vez em hollywood decepcionante  nao teve praticamente nada da historia do manson igual eu achei que teria',
#  'as pessoas podiam fazer crítica de cinema também assim também né  vai lá a minha resenha de era uma vez em hollywood  é um longo filme',
#  'eu preciso ver logo era uma vez em hollywood meu deus do ceu',
#  'era uma vez em… hollywood | um trio premiado https //t co/nhw3xddklq https //t co/q5s0co7maf',
#  'era uma vez em… hollywood | recordando tarantino https //t co/lq1u8zplyt https //t co/g1eobhsgsb',
#  'precisando de companhia pra ir ver era uma vez em hollywood e it 2 cmg  algm se voluntariza  ',
#  'sobre  era uma vez em    hollywood   de tarantino  preciso acordar três dias 1h mais cedo que o habitual pra recuperar o tempo perdido   ⭐️✴️✴️✴️✴️',
#  'assisti de novo era uma vez em hollywood  mas dessa vez trouxe a família  ✌️',
#  'assisti era uma vez em hollywood ontem e que filme bosta nossa nada a ver com o trailer com tudo que falaram',
#  'falando serio  tive a sorte  sem saber  de ver a temporada 2 de mindhunter antes de ver o era uma vez em hollywood”  tarantino colocou varios detalhes identicos aos acontecimentos relacionados ao charles manson ',
#  'era uma vez em hollywood conte cmg pra exatamente tudo',
#  'vi era uma vez em hollywood e achei assim    nem consigo explicar',
#  'fazia tempo que eu não via um filme tão ruim quanto era uma vez em hollywood',
#  'amei era uma vez em hollywood',
#  'eu no filme “era uma vez    em hollywood” do tarantino achando estranho n ter violencia// começa a cena de violência  https //t co/0khykzw80s',
#  'ontem saí da sessão de era uma vez em hollywood muito pistola  as principais cenas q causaram risos e indignação na sala inteira foram as que tinham mulheres roncando  mulheres com os pés sujos e uma mulher sem depilar a axila  mais da metade do público saiu no meio do filme',
#  'que vontade de assistir era uma vez em hollywood de novo',
#  ' luubzy é oq tá no cine  era uma vez em hollywood',
#  'atualização   era uma vez em    hollywood rocketman us vingadores john wick  bacurau',
#  ' karinealexsand2 aposto q foi “era uma vez em hollywood”',
#  'krl preciso ir no cinema pra ver bacurau  it e era uma vez em hollywood   totalizando  14 50   14 50   14 50 = 43 50',
#  'esse mes quero ver bacurau  it 2 e era uma vez em hollywood',
#  'esse  era uma vez em    hollywood  tem 2h40  mas chegaria fácil a 2h se cortasse metade das cenas de personagens dirigindo carros  sem falar em outras sequências desnecessárias  maçante demais ',
#  'quentin tarantini com seu  ótimo  “era uma vez em hollywood” cumpre uma da funções do cinema como produto de entretenimento  neste caso enriquecida por uma bela narrativa e  caracterização de época impecáveis   além das atuações soberbas de um elenco estrelar ',
#  'eu vou soltar uns spoiler de era uma vez em hollywood porque eu preciso comentar do brad pitt matando os assassinos da sharon tate',
#  ' tucarvalho  elenalandau tem um quê também do brad pitt em era uma vez em hollywood',
#  'era uma vez em hollywood é bem maneiro ',
#  ' jefnogueira  ligiatex amadeus é “ícone”  mas na “vibe” dos cinéfilos vou polemizar um pouco  como nos velhos tempos  ligiatex 😂😂😂  indico “era uma vez em hollywood” 😊',
#  'da próxima semana não passa tenho q assistir era uma vez em hollywood',
#  ' aldemirhsn1 assistir era uma vez em hollywood ',
#  'fiquei feliz por ter adivinhado o plot de  era uma vez em hollywood  em uma cena mó away',
#  'oi alguem vai assistir era uma vez em hollywood cmg',
#  'pessoal  vou ver de novo o era uma vez em hollywood  com uma amiga  no shopping vila olimpia  às 20 30    alguém não viu e gostaria de ir   ou quer ver de novo ',
#  '🎬  oscar2020   os mais cotados p melhor ator coadjuvante  até esta data   brad pitt  “era uma vez em hollywood”   al pacino e joe pesci  ambos em “o irlandês”   jamie bell  “rocketman”   anthony hopkins  “os dois papas”  e willem dafoe  “o farol” ',
#  'porra  quero ver bacurau  era uma vez em hollywood e coringa que ainda nem lançou',
#  'tá  sobre oq se trata era uma vez em hollywood      tarantino  você me prometeu',
#  ' aint_no_cherry vc deixou meu braço roxo vendo era uma vez em hollywood',
#  'it capítulo dois pets 2 corgi  top dog yesterday nada a perder 2 era uma vez em   hollywood bacurau velozes e furiosos  hobbs  amp  shaw',
#  'preciso assistir it capítulo 2  bacurau e era uma vez em hollywood 😫😫😫',
#  'a galera ta metendo o pau em  it2   ai não vi bacurau   era uma vez em hollywood nem yesterday  então  it2 vai ficar pra ver na posteridade ',
#  ' bsdaiane quero ver muito era uma vez em hollywood',
#  ' joaomirandasurf era uma vez em hollywood  vi no cinema hj',
#  'bacurau e era uma vez em hollywood foram os dois melhores filmes q eu vi esse ano acho  e não sei dizer qual dos dois eu gostei mais  provavelmente bacurau ',
#  'era uma vez em hollywood que baita filme',
#  'assisti era uma vez em hollywood e no dia seguinte assisti velozes  amp  furiosos   meu qi desceu 8 pontos em um dia velho',
#  'tô cogitando ir no cinema ver era uma vez em hollywood  deve ser muito bom ver um filme do tarantino no cinema',
#  'série de era uma vez em   hollywood  brad pitt revelou que tarantino pensa na ideia https //t co/glyte3zmpu',
#  ' higo_vinicius bacurau acho que vou esperar o  iguinholinhares   mas quero ver it e era uma vez em hollywood',
#  'vi era uma vez em hollywood de novo hj e gostei mais ainda',
#  'assisti era uma vez em hollywood   nota  8 9',
#  'sai de “era uma vez em hollywood” com a sensação de que queria ter gostado mais do filme  o filme é bom  porém o tempo de tela é maior do que o necessário para contar a história que eles queriam  ',
#  ' ovinilciuspovoa  conforme prometido   cães de aluguel  ainda é meu favorito  mas  era uma vez em hollywood  é uma majestosa ode à indústria cinematográfica dos anos 60  quase anos 70  entrou na lista dos filmes que revejo sem pensar duas vezes  nem vi o tempo passar ',
#  'era uma vez em hollywood galera',
#  'acho que eu assisti era uma vez em hollywood errado porque gente       queria dormir o filme inteiro deus do ceu',
#  'vou no  cinemarkoficial e não tem nenhuma seção  com o  era uma vez em hollywood  em pleno sábado',
#  'ontem assisti era uma vez em hollywood   entendi porra nenhuma',
#  'eita  menina  mas chegou tudo de uma vez no cinema da minha cidade  it  era uma vez em hollywood e histórias assustadoras pra contar no escuro  vou gastar todo meu dinheiro no cinema  faltou bacurau  mas fazer o que  pelo menos não é marvel nem disney ',
#  'era uma vez em hollywood  um quadro pintado https //t co/1aef6jgqnq cores de tarantino  excelente escolha de atores com um desempenho brilhante especialmente o di caprio  e o  meu  brad pitt   i love you pitt ❤😊   o up and down    https //t co/1qawygrwrr',
#  'as coisas atrasadas no trampo talvez me impeçam de assistir era uma vez em hollywood  e isso deve ser um puta sinal',
#  ' bastosolrac e era uma vez em hollywood  🤔🤔',
#  'amanhã eu vou ver era uma vez em hollywood   antes tarde do que nunca eu não tenho oq reclamar',
#  'o que eu mais amei em era uma vez em hollywood foi a forma como o tarantino respeitou a história da sharon e isso só mostra que ele é completamente apaixonado pelo cinema e que respeita demais tudo que envolve esse mundo',
#  'se era uma vez em hollywood não ganhar um oscar vou ficar muito puto filme do carai negao',
#  'depois de assistir ‘era uma vez em hollywood’ só me resta uma dúvida  quando teremos uma temporada de the people x charles manson   ',
#  'ontem assisti a era uma vez em    hollywood  o fetiche por pés do tarantino cresce exponencialmente ',
#  'oi alguém aqui já viu era uma vez em hollywood do tarantino  gostaria de debater obrigada',
#  'única coisa que eu queria é ir ver era uma vez em hollywood com a sara',
#  ' solbraga_ era uma vez em hollywood',
#  'vou ver era uma vez em hollywood do tarantino amooo cineminha bb',
#  'esse n vou perder igual perdi era uma vez em hollywood em cartaz    https //t co/6v5nrgbraj',
#  'estou completamente apaixonado pelo filme ‘era uma vez em hollywood’ ❤️❤️❤️',
#  'não consegui assistir era uma vez em hollywood  bacurau e já ta estreando it parte 2  😬😬😬',
#  'era uma vez em hollywood é um filmao fdc',
#  'tarantino é um gênio  era uma vez em hollywood me surpreendeu omg ',
#  ' yagomojaes ta 20 reais a meia amigo  ainda animas   https //t co/uioqd2t0z1 olha os horários',
#  'to com fogo no cu pra ver era uma vez em hollywood',
#  'bom assistir era uma vez em hollywood e eu tô chokito',
#  'pega mal se disser que n curti  era uma vez em hollywood   adoro tarantino  mas n me prendeu  pronto falei ',
#  'tarantino tem interesse em uma série de tv de ‘era uma vez em… hollywood’  releva brad pitt https //t co/eivbzmvhz7',
#  'seila só queria assistir  era uma vez em hollywood ',
#  'era uma vez em hollywood é o filme mais engraçado do tarantino',
#  'hoje eu assisti a era uma vez em    hollywood  filme bom  com a marca registrada do tarantino evidente apenas no último ato  mas o que mais me chamou a atenção foi a metalinguagem entre a história narrada e as histórias dentro da história  tudo muito fluido e natural',
#  'rt  xcruelsummerx  resenha do novo filme do tarantino   https //t co/zwakf23xkf  filme  tarantino',
#  'vi era uma vez em    hollywood ontem e achei muito bom  tem de nazistas sendo queimados com lança chamas até hippies levando lata de ração na cara kkkkk 10/10',
#  'queria assistir era uma vez em hollywood aaaaa',
#  'era uma vez em    hollywood   que loucura ',
#  'melhores filmes que vi esse ano até agora  era uma vez em    hollywood rocketman us vingadores john wick  parabellum',
#  'triste que o cinema de arapiraca não colocou era uma vez em hollywood e bacurau em cartaz  valeu  cinesystem mas nem toda população da cidade gosta só de porcaria  poderia muito bem ter colocado uma sessão de cada filme pelo menos por uma semana ',
#  'vale a pena esperar as quase três horas de era uma vez em hollywood para ver os minutos finais do filme que fica mais tarantinesco do que nunca  https //t co/bcbozvyao8',
#  'lista de filmes que eu e mozi planejamos assistir no cinema neste fim de semana    bacurau   era uma vez em hollywood    yesterday   it    total  em reais  que eu tenho disponível na conta     0',
#  'era uma vez em hollywood é bom  sim  uma apreciação/sátira da terra dos sonhos que queima em fogo baixo  algo incomum para os padrões do tarantino  mas queima ',
#  'semana que vem irei assistir era uma vez em hollywood sem faltaaaa',
#  'meu ranking de filmes do tarantino ficou assim   1 kill bill  1 e 2  2 cães de aluguel 3 pulp fiction 4 bastardos inglórios 5 os oito odiados 6 django livre 7 jackie brown  ainda não vi era uma vez em hollywood https //t co/pu9xwt7j0t',
#  'era uma vez em hollywood tem muito mais o que se discutir que bacurau  bacurau é incrível e poderoso  mas é muito direto e termina em si mesmo  não tem o que falar sobre o filme  o que conversar depois  tá tudo muito explícito e todo mundo entende',
#  'só ontem assisti  era uma vez   em hollywood   que carta de amor que é esse filme   e o que foi brad pitt sem camisa no telhado com 55 anos  quase eu desço a escadinha e vou lamber a tela ',
#  'em busca de amizades sinceras pra conversar sobre era uma vez em hollywood',
#  ' _rodgf amg tudo que eu me frustrei com era uma vez em hollywood eu satisfiz com bacurau  vá ver bacurau',
#  'quero ver era uma vez em hollywood mas não quero ficar 3 horas sentada sozinha no cinema',
#  'quero ver era uma vez em hollywood logo alguem vai cmg',
#  'adorei era uma vez em hollywood kkkkk manow  tem uns dialogos q pqp eu adorei e levaria pra vida  só tem lendas no elenco e alguns momentos cômicos  véi dakota fanning de hippie foi ótimo embora tenha side uma participação rápida  que reviravolta no final ',
#  'assisti pela segunda vez hoje era uma vez em hollywood   decididamente  o filme é  uma obra prima       quentin tarantino  não é um filme de ação típico   é lento e tem 3 horas de duração   tem um final arrebatador    https //t co/aojl9xcozz',
#  ' uselolja era uma vez em hollywood ',
#  'brad pitt confirma que era uma vez em… hollywood ganhará uma série derivada https //t co/ctbiqefkpu https //t co/xlu2do08gn',
#  'e a vontade de ir no cinema de novo pra rever era uma vez em hollywood filme 10/10',
#  ' caroleaks o era uma vez em hollywood eu tenho ctz que ganha o brad pitt como melhor ator coadjuvante e só não posso dizer de melhor ator e filme pq ainda n assisti o joker e o the irishman  acho que melhor diretor o tarantino pode ganhar  mas como eu disse the irishman',
#  'era uma vez em hollywood é o filme palmeiras  elenco caro e excelente mas podia funcionar melhor 👍👍',
#  'terça foi dia de era uma vez    em hollywood cm duda  quinta assisti bacurau cm ju e amanda  e hj assisti it  capítulo dois',
#  'vi era uma vez em hollywood ontem e achei mais ou menos  mas o final vale o resto',
#  ' eudiegomarques tô doida pra ver yesterday e era uma vez em hollywood  it eu passo hahahahahaha ',
#  ' preduu_rocha vamo ver era uma vez em hollywood primeirooooo daqui a pouco eles tiram essa merda de cartaz aí eu vou lá quebrar todo mundo',
#  'tudo que eu queria era ir no cinema ver era uma vez em     hollywood  mas tá passando só no colinas',
#  'sobre era uma vez em hollywood  o filme do tarantino que não brilha por ser do tarantino  dicaprio tá digno de oscar  o diretor trabalha com metalinguagem dentro de metalinguagem em alguns momentos que é de bater palma  brad pitt aos  50 anos tá em talvez no seu melhor papel  ',
#  'era uma vez em hollywood  o filme foi bom como esperava de uma maneira bem diferente  gostei da mudança do tarantino aqui  tratar o cotidiano dos protagonistas pra no final a gente temer um fato só com outros envolvidos      acho que não vai ser um filme pra tds  ah que trilha  lt 3 https //t co/xkcfagbyr9',
#  ' darlanbuffon  ddboechat simmm  era uma vez em hollywood  ainda tá nos cinemas',
#  'era uma vez em hollywood premiere em  cannes   novo filme de  tarantino já tem trailer e estreia em https //t co/19ksptpdq7  bradpitt',
#  'tô achando q vai chegar no cinema de pbi  it 2  e  era uma vez em hollywood  ao mesmo tempo',
#  'era uma vez em hollywood é ruim demais  que decepção',
#  'não assistam  era uma vez em hollywood  pq se vc for burro a  q nem eu  n vai entender nada nadinha ',
#  'atrasada dando minhas considerações sobre era uma vez em hollywood  assistam  tarantino   bradd pitt   leo dicaprio   margot robbie  ',
#  'quem não gostou da obra prima que foi era uma vez em hollywood é pq não entendeu o conceito',
#  'uma suposta série derivada de era uma vez em    hollywood vem aí  aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#  'era uma vez em hollywood saiu de cartaz 🥺',
#  ' pedrottienzo bacurau é melhor q era uma vez em hollywood  extremamente superestimado  minha opiniao ',
#  ' eleganterick to levando mt fé não depois de era uma vez em hollywood do tarantino ter sido uma tremenda decepção pra mim',
#  'utilidade pública para o acre  it capítulo 2 estreou com duas sessões legendadas  ainda assim  bacurau  yesterday e era uma vez em    hollywood estão fora de cartaz  os dois primeiros ficaram apenas uma semana nas salas  nada a perder 2 segue com duas sessões ',
#  'o vontade de ir no cinema  ver era uma vez em hollywood 😁',
#  'é isso gente infelizmente não vou assistir era uma vez em hollywood de novo pq o cinépolis vive mudando de horário',
#  'tô doida pra ver era uma vez em hollywood',
#  'não assista o filme era uma vez em hollywood do tarantino a n ser que vc queira ficar 2h 40min em um sala sem entender um puto do que tá acontecendo',
#  ' carlusedoardu a favorita é do ano passado  assistiu bacurau  bacurau e parasita são meus preferidos  mas também adorei us e era uma vez em hollywood',
#  'um drink no inferno pulp fiction kill bill         era uma vez em hollywood          mindhuter  https //t co/5x0tnakmii',
#  'indo assistir era uma vez em hollywood pela segunda vez',
#  'ontem eu vi era uma vez em hollywood  do tarantino eu saí da seção meio bugado  mas dps de dar uma analisada melhor eu fiquei caralho que filme genial',
#  'era uma vez em hollywood me parece um filme que é considerado genial por causa de uma unica coisa  https //t co/14f8qf6vms',
#  ' lelet_xavier tenho que assistir esse e depois era uma vez em hollywood',
#  'assisti era uma vez em hollywood e tqrantino virou genio  genio com letras garrafais  o que ele fez nesse filme é uma coisa pra poucos  pra quem entende o poder da arte que realiza   e o proximo que vier com mimimi de supervalorizado  diretor de hetero eu vou mandar tomar no cu',
#  'a meta de hoje eh chegar no cinema do dragão ver era uma vez em hollywood',
#  'vou ter que trocar o churras de um amigo por era uma vez em hollywood',
#  'era uma vez em hollywood  saiba o que brad pitt tem a dizer sobre possível série derivada https //t co/jvvxpa0ssy',
#  'eu quero ve era uma vez em hollywood dnv so pelo final',
#  'o coringa  um filme que me ganhou num trailer que vi sem querer  enquanto aguardava no cinema para ver  era uma vez em     hollywood   ganhou o leão de ouro     https //t co/fzwhcvkwsb',
#  'quero muito assistir bacurau e era uma vez em hollywood',
#  'quero opiniões sobre o era uma vez em hollywood ⬇️⬇️⬇️',
#  ' slccarmo era uma vez em hollywood    com o pitt e o dicaprio os 8 odiados ainda não vi não',
#  'ontem assisti  era uma vez em     hollywood  e sai de lá assim https //t co/nqjre37tlb',
#  'é real  não dá mais pra morar em rondonópolis  além de não ter vindo era uma vez em hollywood pro cinema daqui os caras só me trouxeram cópias dubladas de it',
#  ' giuliascavuzzi_ era uma vez em hollywood',
#  'último filme que viu  — era uma vez em hollywood https //t co/ntbkop5l4r',
#  'mano era uma vez em hollywood é bom demais tá maluco',
#  'eu queria muito assistir era uma vez em hollywood mas também queria muito assistir yesterday de novo',
#  'e minha amiga que foi ver era uma vez em hollywood naquela segunda feira que escureceu as 15h  ela entrou no cinema tipo a 13h e tinham falado que o filme era muito longo  saiu tava tudo escuro  porra quanto tempo eu fiquei no cinema    ',
#  'ah  coé    eu ia assistir era uma vez em hollywood amanhã e o filme sai de cartaz        tomar no cu hein',
#  'ainda sobre  era uma vez em hollywood   a presença de charles manson e sua  família   assim como toda a áurea de uma los angeles dos anos 60  quase anos 70  é um espetáculo e um  soco  à parte  são quase três horas de nostalgia  diversão e viagem na metalinguagem tarantinesca ',
#  'classifiquei era uma vez em    hollywood  2019  9/10   imdb https //t co/gua8tj5ams',
#  ' caetanobezerra eu ontem assistindo o  era uma vez    em hollywood  e pensando no quanto estava odiando o filme  daí apareceu uma cena que me fez elogiar a fotografia  porém continuei pensando  ainda assim o filme é ruim  ',
#  ' vitoriaqueirozm ai vi era uma vez em hollywood c minha irmã pois fiquie c medo de tu dizer q n podia',
#  'esse ato final de era uma vez em hollywood  pqp  vontade de assistir novamente já',
#  'era uma vez    em hollywood  2019  dir  quentin tarantino   ⭐️⭐️⭐️⭐️ https //t co/iuqdvhbfuo',
#  'era uma vez    em hollywood  que filme sensacional  demorou mais consegui achar um cinema com ele 🤩',
#  ' isabnicolini era uma vez em hollywood e bacurau hahahahaha socorro  são muitos filmes bons',
#  'era uma vez em hollywood  8 8/10',
#  'assim como quero era uma vez em hollywood  histórias assustadoras para contar no escuro  etc   sdds um filminho bom',
#  'impacto cultural            █          \u3000\u3000          █\u3000                  █\u3000                  █\u3000                           ＿    bacurau    era uma vez em hollywood',
#  'faz um mês que eu vi era uma vez em hollywood e ainda não parei de escutar a trilha sonora desse filme',
#  ' josiasteofilo josias  assistiu era uma vez em hollywood  curtiu ',
#  ' davidbowiezinho tô doida pra assistir o era uma vez em hollywood',
#  'assisti bacurau  era uma vez em hollywood e it2 nós últimos dias  nessa sequência  o ranking do melhor pro pior  bacurau  it2 e era uma vez em hollywood  tarantino tava com preguiça viu  depois da obra prima os oito odiados me vem com esse filme meia boca  😒 https //t co/gkzpjrxpq3',
#  'e pensar que era pra eu tá começando a assistir era uma vez em hollywood exatamente agora  tristeza',
#  'tô impactada  o que sai decepcionada com it sai apaixonada por era uma vez em hollywood 💜💜💜💜💜 pqp  eu acho que nem dormir eu vou de tão agitada eu fiquei com esse final   pqp eu tô muito apaixonadinha é isso',
#  ' guileumis kakkaka to comparando lançamentos e bacurau colocou era uma vez em hollywood muito no chinelooooo',
#  'porra eu morri de rir na cena do bruce lee  que isso aqueles gritinhos são os melhores kkkkkkk era uma vez em hollywood é o melhor filme ♥️',
#  'putz  agora chegou era uma vez em hollywood no cinema q eu vou  mas só vou poder assistir pra lá de outubro  já era',
#  'bacurau e era uma vez em hollywood não são superestimados  nem subestimados  eles são lançamentos  é como se chama um filme que acabou de ser lançado  daí as pessoas assitem e falam sobre  lançamento  novidade  etc ',
#  'bastardos inglórios   ok era uma vez    em hollywood   ok pulp  fiction   ok django livre   ok  faltam 6 filmes pra eu zerar o tarantino',
#  ' walterporto  kylebuchanan e ele em era uma vez em hollywood  the best ',
#  'eu n sei pq caralhos tao comparando “era uma vez em hollywood   ” e “bacurau”  2 filmao da porra e a gente devia é estar feliz por ter eles pra assistir ao invés de ficar diminuindo/comparando eles',
#  'uma hora e vinte minutos de  era uma vez em hollywood  e ate agora não aconteceu absolutamente nada nesse filme  tomar no cu  tarantino',
#  ' vihhlee  rafaello1313 o cara fala que não é bom  porque é só mais um trouxa que não estudou a história  e nem captou a chuva de referências da época  que o diretor colocou em era uma vez em hollywood  sem falar nos recordes de bilheteria e críticas positivas de quem  de fato  entende ',
#  'assistam era uma vez em hollywood',
#  'fui ver o era uma vez em hollywood e foi só o melhor filme de sempre  quero ir ver outra vez 😭😭',
#  'era uma vez em hollywood 2019  https //t co/0gvzdeguhy',
#  'inadmissível eu até hoje não ter ido assistir era uma vez em hollywood',
#  'bucurau  gt  era uma vez em hollywood',
#  'bom    depois de 3 semanas tentando  finalmente consegui assistir era uma vez em hollywood    gata  tarantino vc sabem qm é ',
#  'impacto cultural            █          \u3000\u3000          █\u3000                  █\u3000                  █\u3000                           ＿   bacurau                      era uma vez                                     em hollywood',
#  ' peixeaquatico essas propagandas do dicaprio se parecem demais com os trailers do personagem do dicaprio em  era uma vez em hollywood ',
#  'nossa  faz mais de um mês que não vou no cinema  não tá tendo lançamentos legais e os poucos filmes bons que saem o cinema daqui não passa  nunca vou superar o descaso com era uma vez em hollywood ',
#  'era uma vez em hollywood vai virar série https //t co/sato2stdkp',
#  'ninguém me pediu  mas vou fazer um tuíte com comentários sobre os assuntos em alta   1  dá para ver bacurau e era uma vez em    hollywood sem menosprezar nenhum dos dois  2  não traiu  mas deveria  3  o novo iphone nem é tão feio assim  4  é uma cpmf piorada  não vai passar ',
#  ' julialcastrov era uma vez em hollywood  tem o leornado dicaprio',
#  'no refil  queissoassim 158   saudades do que a gente não viveu     era uma vez em    hollywood    https //t co/ewarof4i0r  margotrobbie  mayahawke  xaxá  anos2010  quentintarantino',
#  'na boa  não estou entendendo essa briguinha atoa  essa competição ridícula entre bacural e era uma vez em    hollywood  há menos de um mês tarantino ainda era herói descolados  daí do nada o cara virou chacota para os mesmo descolados  essa “lacração” tá passando dos limites  https //t co/ffzwp9xmsu',
#  'era uma vez em hollywood https //t co/niyxxjtvko',
#  'se forçar mais caga  já faz mais de um mês da estreia de era uma vez em hollywood  logo a bilheteria já caiu  https //t co/df2pag7g1e',
#  'quando alguém quiser lacrar e dar a ideia de q há uma disputa entre bacurau e  once upon a time    in hollywood  era uma vez    em hollywood  pergunte apenas “como essa disputa surgiu ”  e se divirta c a resposta',
#  'era uma vez em hollywood segundo melhor por enquanto',
#  'o tal charlie dos hippies  menção  do era uma vez em hollywood era o charles manson   ',
#  ' nflnaespn acho que vc quis dizer era uma vez em hollywood  bacurau é de um diretor brasileiro 😄',
#  'ranking seleção oficial cannes 2019   1  parasita 2  era uma vez em hollywood 3  bacurau 4  dor  amp  glória         5  the dead don t die',
#  ' felipesimon tô no mesmo barco    só sei q saí do cinema feliz com o dinheiro gasto e sem dúvida veria de novo antes de tentar ver pela primeira ver o era uma vez em hollywood',
#  'vim ao shopping assistir a bacurau e era uma vez em hollywood ',
#  ' kmendoncafilho  alexluizbr o cinema é lindo  oq estraga é cinéfilo caga regra e treteiro  o meu coração tem espaço de sobra pra bacurau e era uma vez em    hollywood',
#  'ansiosa p assistir era uma vez em hollywood',
#  'na moral mesmo era uma vez em hollywood é sensacional  assistam',
#  'era uma vez em    hollywood https //t co/yemnbizgwa escrevi sobre o filme lá para o  bloggallerya',
#  'cena deletada de era uma vez em hollywood pode ser uma das melhores de tarantino https //t co/dtdzlswihl',
#  'assisti  era uma vez em    hollywood  e achei bem chatinho  mas a surpresa é que tocou inteira a minha preferida dos rolling stones https //t co/t7xtxih6do',
#  'era uma vez em hollywood é muito bom',
#  ' ingfcps e fizeram uma puta justiça  c vai entender quando ver pq q chama “era uma vez em hollywood”',
#  ' marxlboro era uma vez em hollywood foi o único filme que eu vi no cinema que me deu sono',
#  ' 102  era uma vez em    hollywood  2019  ⭐️⭐️⭐️⭐️⭐️ https //t co/nkp9jrch8y',
#  'será se já tem torrent de era uma vez em hollywood ',
#  'ainda não vi era uma vez em hollywood  mas logo verei para saber em que lugar colocaria na ordem dos meus filmes tarantinescos  que é    1  pulp fiction 2  cães de aluguel 3  kill bill 4  bastardos inglórios 5  prova de morte 6  jackie brown  7  django  8  oito odiados ',
#  ' kmendoncafilho achei bacurau melhor e era uma vez em hollywood um dos piores do tarantino  acho que ele tava com preguiça ',
#  ' kmendoncafilho eu fui pra ver a pré estreia de bacurau em goiânia mas estava mais que lotado e disseram que não iriam abrir sessão extra  me restou ir em outro lugar assistir era uma vez em hollywood  mas na minha opinião o trailer que vi de bacurau foi melhor que as horas em euveh',
#  'qnd eu assistir era uma vez em hollywood e bacurau ainda ser meu filme preferido do ano friendship with tarantino is over now kleber mendonça filho is my bff',
#  ' carlos_history  misterpinkeyes  kmendoncafilho putz  era uma vez em hollywood é muito bom  muito   ',
#  'era uma vez em hollywood um filme bem arrastado q eu quase dormir em umas partes do filme',
#  'era uma vez em hollywood vai virar série  https //t co/2zgxknpqru',
#  ' lustosadaniel ja assistiu “era uma vez em hollywood”    eu tavu querendo podiamos marcar um fds pra ja assistir os dois',
#  'quarta feira   cine passeio = programação nova  🤩🎬  entram em cartaz os longas  era uma vez em    hollywood   de quentin tarantino  e o nacional  legalidade   que apresenta o cenário político brasileiro de 1961    🍿 confira a programação completa  https //t co/8tezuewazs https //t co/rfjlgsobpm',
#  'era uma vez em hollywood bom d  tarantino já fez melhores mas ainda assim amei',
#  'ok então estou atrasada para a semana de arquitetura e mto adiantada para o trabalho    finalmente indo assistir era uma vez em hollywood',
#  'não aguento mais a joyce falando mal de era uma vez em hollywood vou perder as estribeiras com essa cinéfila 😡😡😡😡',
#  'o final de “era uma vez em    hollywood” me emocionou ❤️ de fato  um tarantino bem diferente ',
#  'bacurau ou era uma vez em hollywood',
#  ' davidbowiezinho ai eu ainda não vi bacurau e tô morrendo por isso  era uma vez em hollywood eu vi e adorei',
#  ' teledramaturgia essa é a cena de sharon tate no filme  arma secreta contra matt helm  que aparece no filme  era uma vez em hollywood  https //t co/lktximnkan',
#  'impressão minha ou era uma vez em hollywood foi um flop por aqui ',
#  'bacurau  é um puta filmaço era uma vez em hollywood  também é muito foda ',
#  'o que você achou de era uma vez em hollywood — eu gostei me diverti bastante e tal achei bem feito apesar de não ir muito além disso  porém valeu a pena 7/10 https //t co/hhiqljz3c9',
#  'era uma vez em hollywood premiere em  cannes   novo filme de  tarantino já tem trailer e estreia em https //t co/djahf947ev  bradpitt',
#  'na semana que saiu era um vez em hollywood eu fui comentar com uma amiga que queria ver  ela não fazia a mínima ideia de quem era e depois eu fui checar e descobrir que ninguém na minha sala conhecia ele',
#  ' renatoaogimenes viu o era uma vez em hollywood  tem hush na trilha sonora  que é muito boa  um bom retrato da época ',
#  ' omalestafeito  id_error_6 a ideia é muito boa e o david fincher também ajuda bastante  hoje vi o  era uma vez em hollywood  e lembrei me das conversas com o ted bundy e o charles manson  a cena dos óculos é muito reveladora da personalidade do último ',
#  ' kmendoncafilho era uma vez em hollywood é uma merda kkk só faz sucesso pq é americano e feito por um branco de hollywood   pra não ser injusto  os último 15min do filme são engraçados  mas porra  3 hrs pra 15 min valerem a pena   meu tempo de vida vale mais https //t co/ijgizht1ca',
#  'qual o ultimo filme que vc viu no cinema  — era uma vez em hollywood https //t co/th0cnvmtls',
#  'ta passando era uma vez em hollywood aindaaa pois eu vou hoje mesmo  cine sao carlos vc nao cansa de ser tão perfeito      ',
#  ' marianahavilaa era uma vez em hollywood',
#  'ai queria ser só tipo a hippie bonitinha de era uma vez em hollywood']

# %% [markdown]
# ## Tabela: 0, 1, 2. - Todos

# %%
#Aqui foi feito o calculo das tabelas de frequência absoluta e relativa para todos os nosso tweets.
tabela_correta
# Out:
#     Classificação                                             tweets
# 0               2   frckribery recebi hoje e só lembrei de certas...
# 1               0  que no caso são  bacurau  era uma vez em holly...
# 2               0         eduu_miranda era uma vez gore em hollywood
# 3               0  eu quero muito assistir bacurau e era uma vez ...
# 5               1  vai sair uma versão de 4 horas de era uma vez ...
# 6               2  bacurau dá de 10 x 0 em era uma vez em hollywo...
# 9               2  quanto mais leio/ouço sobre  era uma vez em   ...
# 10              1  boa noite seguidores  hoje a crítica vai para ...
# 11              0   era uma vez em hollywood  ultrapassa a marca ...
# 12              0  dá rt se hoje você   tá feliz tá animado tá an...
# 15              0  a fila tá enorme  esquece  vou ver era uma vez...
# 16              0  nao ta passando mais bacurau nao ta passando m...
# 17              1  eu só queria registrar que vi era uma vez em h...
# 19              0  ontem eu descobri assistindo era uma vez     e...
# 20              2    quase dormi assistindo era uma vez em hollywood
# 21              0  bixo  faz uns 6 meses que não vou no cinema po...
# 22              0  quem eh que vamo assisti bacurau e it  se era ...
# 23              0   luide  helioflores  pedrosazevedo era uma vez...
# 24              0  era só uma companhia pra assistir era uma vez ...
# 26              1  era uma vez em hollywood é muito bom gente pra...
# 27              1  assisti  era uma vez em hollywood    e ainda e...
# 29              0  it  a coisa   cap 2 bacurau era uma vez em hol...
# 30              1  era uma vez em    hollywood é um puta filme do...
# 31              2   josiasteofilo não consegui assistir o era uma...
# 33              0  quem vai comigo no cinema ver era uma vez em h...
# 34              0  well  well  agora part 2 do dia no cinema  ass...
# 36              1  era uma vez em hollywood = dahora cena final s...
# 37              0  eu preciso assistir era uma vez em hollywood o...
# 38              0   chibnetti e eu q tenho q emendar era uma vez ...
# 39              0   reachsaravah é mais violento que “era uma vez...
# ..            ...                                                ...
# 51              0   102  era uma vez em    hollywood  2019  ⭐️⭐️⭐...
# 52              0  será se já tem torrent de era uma vez em holly...
# 53              0  ainda não vi era uma vez em hollywood  mas log...
# 54              1   kmendoncafilho achei bacurau melhor e era uma...
# 55              0   kmendoncafilho eu fui pra ver a pré estreia d...
# 56              0  qnd eu assistir era uma vez em hollywood e bac...
# 57              1   carlos_history  misterpinkeyes  kmendoncafilh...
# 58              2  era uma vez em hollywood um filme bem arrastad...
# 59              0  era uma vez em hollywood vai virar série  http...
# 60              0   lustosadaniel ja assistiu “era uma vez em hol...
# 61              0  quarta feira   cine passeio = programação nova...
# 62              1  era uma vez em hollywood bom d  tarantino já f...
# 63              0  ok então estou atrasada para a semana de arqui...
# 64              2  não aguento mais a joyce falando mal de era um...
# 65              1  o final de “era uma vez em    hollywood” me em...
# 66              0                bacurau ou era uma vez em hollywood
# 67              1   davidbowiezinho ai eu ainda não vi bacurau e ...
# 68              0   teledramaturgia essa é a cena de sharon tate ...
# 69              0  impressão minha ou era uma vez em hollywood fo...
# 70              1  bacurau  é um puta filmaço era uma vez em holl...
# 71              1  o que você achou de era uma vez em hollywood —...
# 72              0  era uma vez em hollywood premiere em  cannes  ...
# 73              0  na semana que saiu era um vez em hollywood eu ...
# 74              1   renatoaogimenes viu o era uma vez em hollywoo...
# 75              0   omalestafeito  id_error_6 a ideia é muito boa...
# 76              2   kmendoncafilho era uma vez em hollywood é uma...
# 77              0  qual o ultimo filme que vc viu no cinema  — er...
# 78              0  ta passando era uma vez em hollywood aindaaa p...
# 79              0            marianahavilaa era uma vez em hollywood
# 80              0  ai queria ser só tipo a hippie bonitinha de er...
#
# [301 rows x 2 columns]

# %% [markdown]
# #### Frequências absolutas

# %%
#transformando as informações da tabelas em strings
tabela_str_total = tabela_correta.tweets.to_string()

limpo_split = pd.Series(tabela_str_total.split())
#obtendo a frequência absoluta
tabela_freq_abs_total = limpo_split.value_counts()
tabela_freq_abs_total
total_valores=len(tabela_freq_abs_total)

# %% [markdown]
# #### Frequências relativas

# %%
#Obtendo a frequência relativa
tabela_freq_rel_total = limpo_split.value_counts(True)
tabela_freq_rel_total
# Out:
# uma               0.069408
# era               0.068092
# vez               0.063158
# em                0.061184
# hollywood         0.041776
# de                0.018092
# ...               0.018092
# que               0.016447
# e                 0.013487
# eu                0.012500
# o                 0.012171
# assistir          0.010197
# no                0.009211
# ver               0.009211
# não               0.009211
# é                 0.009211
# a                 0.008553
# um                0.006908
# bacurau           0.006908
# do                0.005921
# filme             0.005921
# assisti           0.005592
# vi                0.004934
# cinema            0.004934
# vou               0.004934
# e...              0.004276
# pra               0.004276
# mais              0.004276
# ontem             0.003618
# quero             0.003289
#                     ...
# premiado          0.000329
# perdi             0.000329
# 277               0.000329
# danado            0.000329
# 257               0.000329
# carlos_history    0.000329
# trio              0.000329
# indicados         0.000329
# co/0g...          0.000329
# ido               0.000329
# inventado         0.000329
# pena              0.000329
# tão               0.000329
# serio             0.000329
# 251               0.000329
# trampo            0.000329
# 170               0.000329
# ddboechat         0.000329
# 164               0.000329
# dizer             0.000329
# gremio            0.000329
# ultimo            0.000329
# sens...           0.000329
# bsdaiane          0.000329
# segundo           0.000329
# 🤦🏼‍♀️             0.000329
# trocar            0.000329
# barco             0.000329
# 90                0.000329
# 289               0.000329
# Length: 971, dtype: float64

# %% [markdown]
# ## Tabela: 1, 2 - Relevantes

# %%
#Aqui separamos a tabela principal em apenas tweets relevantes, ou seja, classificados em 1 e 2.
excel_relevantes=tabela_correta.loc[tabela_correta['Classificação']!=0]
excel_relevantes
# Out:
#      Classificação                                             tweets
# 0                2   frckribery recebi hoje e só lembrei de certas...
# 5                1  vai sair uma versão de 4 horas de era uma vez ...
# 6                2  bacurau dá de 10 x 0 em era uma vez em hollywo...
# 9                2  quanto mais leio/ouço sobre  era uma vez em   ...
# 10               1  boa noite seguidores  hoje a crítica vai para ...
# 17               1  eu só queria registrar que vi era uma vez em h...
# 20               2    quase dormi assistindo era uma vez em hollywood
# 26               1  era uma vez em hollywood é muito bom gente pra...
# 27               1  assisti  era uma vez em hollywood    e ainda e...
# 30               1  era uma vez em    hollywood é um puta filme do...
# 31               2   josiasteofilo não consegui assistir o era uma...
# 36               1  era uma vez em hollywood = dahora cena final s...
# 41               1  nem vi a derrota do gremio  fui ver  era uma v...
# 49               1  interessante que quanto mais eu reflito sobre ...
# 55               1   surtemprala 🤦🏼‍♀️ meu deus  só um dos melhore...
# 58               1  o personagem do brad pitt em era uma vez em ho...
# 63               1  dos indicados à palma de ouro no último festiv...
# 69               1    leonthomasburke era uma vez em hollywood é foda
# 70               1  tava ouvindo o rapaduracast sobre era uma vez ...
# 76               1  e gostei que em era uma vez em hollywood tem r...
# 78               1  eu não sabia que tinha personagens que existir...
# 83               1   aaugustiado fui ver o era uma vez em hollywoo...
# 86               2  ai eu achei era uma vez em hollywood decepcion...
# 87               2  as pessoas podiam fazer crítica de cinema tamb...
# 93               2  sobre  era uma vez em    hollywood   de tarant...
# 94               1  assisti de novo era uma vez em hollywood  mas ...
# 95               2  assisti era uma vez em hollywood ontem e que f...
# 97               1  era uma vez em hollywood conte cmg pra exatame...
# 100              2  fazia tempo que eu não via um filme tão ruim q...
# 101              1                      amei era uma vez em hollywood
# ..             ...                                                ...
# 292              2   caetanobezerra eu ontem assistindo o  era uma...
# 294              1  esse ato final de era uma vez em hollywood  pq...
# 299              1  era uma vez    em hollywood  que filme sensaci...
# 0                1   isabnicolini era uma vez em hollywood e bacur...
# 1                1                   era uma vez em hollywood  8 8/10
# 4                1  faz um mês que eu vi era uma vez em hollywood ...
# 9                1  tô impactada  o que sai decepcionada com it sa...
# 11               1  porra eu morri de rir na cena do bruce lee  qu...
# 16               1  eu n sei pq caralhos tao comparando “era uma v...
# 17               2  uma hora e vinte minutos de  era uma vez em ho...
# 18               1   vihhlee  rafaello1313 o cara fala que não é b...
# 19               1                  assistam era uma vez em hollywood
# 20               1  fui ver o era uma vez em hollywood e foi só o ...
# 36               1  era uma vez em hollywood segundo melhor por en...
# 40               1   felipesimon tô no mesmo barco    só sei q saí...
# 44               1  na moral mesmo era uma vez em hollywood é sens...
# 47               2  assisti  era uma vez em    hollywood  e achei ...
# 48               1               era uma vez em hollywood é muito bom
# 50               2   marxlboro era uma vez em hollywood foi o únic...
# 54               1   kmendoncafilho achei bacurau melhor e era uma...
# 57               1   carlos_history  misterpinkeyes  kmendoncafilh...
# 58               2  era uma vez em hollywood um filme bem arrastad...
# 62               1  era uma vez em hollywood bom d  tarantino já f...
# 64               2  não aguento mais a joyce falando mal de era um...
# 65               1  o final de “era uma vez em    hollywood” me em...
# 67               1   davidbowiezinho ai eu ainda não vi bacurau e ...
# 70               1  bacurau  é um puta filmaço era uma vez em holl...
# 71               1  o que você achou de era uma vez em hollywood —...
# 74               1   renatoaogimenes viu o era uma vez em hollywoo...
# 76               2   kmendoncafilho era uma vez em hollywood é uma...
#
# [112 rows x 2 columns]

# %% [markdown]
# ## Tabela de frequência - Bom

# %% [markdown]
# #### Frequências absolutas

# %%
#Separando a tabela do em '1' (bom) para  obter a frequência absoluta dos tweets
excel_bom=excel_relevantes.loc[excel_relevantes['Classificação']==1]
excel_bom
# Out:
#      Classificação                                             tweets
# 5                1  vai sair uma versão de 4 horas de era uma vez ...
# 10               1  boa noite seguidores  hoje a crítica vai para ...
# 17               1  eu só queria registrar que vi era uma vez em h...
# 26               1  era uma vez em hollywood é muito bom gente pra...
# 27               1  assisti  era uma vez em hollywood    e ainda e...
# 30               1  era uma vez em    hollywood é um puta filme do...
# 36               1  era uma vez em hollywood = dahora cena final s...
# 41               1  nem vi a derrota do gremio  fui ver  era uma v...
# 49               1  interessante que quanto mais eu reflito sobre ...
# 55               1   surtemprala 🤦🏼‍♀️ meu deus  só um dos melhore...
# 58               1  o personagem do brad pitt em era uma vez em ho...
# 63               1  dos indicados à palma de ouro no último festiv...
# 69               1    leonthomasburke era uma vez em hollywood é foda
# 70               1  tava ouvindo o rapaduracast sobre era uma vez ...
# 76               1  e gostei que em era uma vez em hollywood tem r...
# 78               1  eu não sabia que tinha personagens que existir...
# 83               1   aaugustiado fui ver o era uma vez em hollywoo...
# 94               1  assisti de novo era uma vez em hollywood  mas ...
# 97               1  era uma vez em hollywood conte cmg pra exatame...
# 101              1                      amei era uma vez em hollywood
# 104              1  que vontade de assistir era uma vez em hollywo...
# 113              1  quentin tarantini com seu  ótimo  “era uma vez...
# 121              1            era uma vez em hollywood é bem maneiro
# 123              1   jefnogueira  ligiatex amadeus é “ícone”  mas ...
# 129              1  pessoal  vou ver de novo o era uma vez em holl...
# 142              1  bacurau e era uma vez em hollywood foram os do...
# 143              1           era uma vez em hollywood que baita filme
# 149              1  vi era uma vez em hollywood de novo hj e goste...
# 150              1       assisti era uma vez em hollywood   nota  8 9
# 152              1   ovinilciuspovoa  conforme prometido   cães de...
# ..             ...                                                ...
# 245              1  quem não gostou da obra prima que foi era uma ...
# 262              1  indo assistir era uma vez em hollywood pela se...
# 263              1  ontem eu vi era uma vez em hollywood  do taran...
# 266              1  assisti era uma vez em hollywood e tqrantino v...
# 271              1  eu quero ve era uma vez em hollywood dnv so pe...
# 283              1  mano era uma vez em hollywood é bom demais tá ...
# 289              1  ainda sobre  era uma vez em hollywood   a pres...
# 294              1  esse ato final de era uma vez em hollywood  pq...
# 299              1  era uma vez    em hollywood  que filme sensaci...
# 0                1   isabnicolini era uma vez em hollywood e bacur...
# 1                1                   era uma vez em hollywood  8 8/10
# 4                1  faz um mês que eu vi era uma vez em hollywood ...
# 9                1  tô impactada  o que sai decepcionada com it sa...
# 11               1  porra eu morri de rir na cena do bruce lee  qu...
# 16               1  eu n sei pq caralhos tao comparando “era uma v...
# 18               1   vihhlee  rafaello1313 o cara fala que não é b...
# 19               1                  assistam era uma vez em hollywood
# 20               1  fui ver o era uma vez em hollywood e foi só o ...
# 36               1  era uma vez em hollywood segundo melhor por en...
# 40               1   felipesimon tô no mesmo barco    só sei q saí...
# 44               1  na moral mesmo era uma vez em hollywood é sens...
# 48               1               era uma vez em hollywood é muito bom
# 54               1   kmendoncafilho achei bacurau melhor e era uma...
# 57               1   carlos_history  misterpinkeyes  kmendoncafilh...
# 62               1  era uma vez em hollywood bom d  tarantino já f...
# 65               1  o final de “era uma vez em    hollywood” me em...
# 67               1   davidbowiezinho ai eu ainda não vi bacurau e ...
# 70               1  bacurau  é um puta filmaço era uma vez em holl...
# 71               1  o que você achou de era uma vez em hollywood —...
# 74               1   renatoaogimenes viu o era uma vez em hollywoo...
#
# [82 rows x 2 columns]

# %%
#Transformando em string
tabela_str_bom = excel_bom.tweets.to_string()
limpo_split = pd.Series(tabela_str_bom.split())
#Obtendo tabela absoluta
tabela_freq_abs_bom = limpo_split.value_counts()
tabela_freq_abs_bom
# x=len(tabela_freq_abs_bom)
# Out:
# uma             65
# era             61
# vez             60
# em              60
# hollywood       45
# ...             17
# que             16
# de              15
# o               15
# é               14
# e               13
# eu              12
# vi               9
# assisti          7
# bom              7
# um               7
# filme            7
# a                6
# sobre            5
# do               5
# não              5
# só               5
# assistir         4
# ontem            4
# bacurau          4
# novo             4
# ver              4
# mais             3
# foi              3
# final            3
#                 ..
# 49               1
# conforme         1
# três             1
# 8/10             1
# barco            1
# 16               1
# 26               1
# atrasada         1
# manow            1
# demais           1
# amadeus          1
# derrota          1
# boa              1
# se               1
# sa...            1
# 223              1
# mês              1
# prometido        1
# caralhos         1
# aaugustiado      1
# b...             1
# hollywo...       1
# rafaello1313     1
# hj               1
# porra            1
# 237              1
# melhores         1
# festiv...        1
# gente            1
# já               1
# Length: 341, dtype: int64

# %% [markdown]
# #### Frequências relativas

# %%
#Obtendo a frequência relativa bom
tabela_freq_rel_bom = limpo_split.value_counts(True)
tabela_freq_rel_bom
# Out:
# uma             0.077289
# era             0.072533
# vez             0.071344
# em              0.071344
# hollywood       0.053508
# ...             0.020214
# que             0.019025
# de              0.017836
# o               0.017836
# é               0.016647
# e               0.015458
# eu              0.014269
# vi              0.010702
# assisti         0.008323
# bom             0.008323
# um              0.008323
# filme           0.008323
# a               0.007134
# sobre           0.005945
# do              0.005945
# não             0.005945
# só              0.005945
# assistir        0.004756
# ontem           0.004756
# bacurau         0.004756
# novo            0.004756
# ver             0.004756
# mais            0.003567
# foi             0.003567
# final           0.003567
#                   ...
# 49              0.001189
# conforme        0.001189
# três            0.001189
# 8/10            0.001189
# barco           0.001189
# 16              0.001189
# 26              0.001189
# atrasada        0.001189
# manow           0.001189
# demais          0.001189
# amadeus         0.001189
# derrota         0.001189
# boa             0.001189
# se              0.001189
# sa...           0.001189
# 223             0.001189
# mês             0.001189
# prometido       0.001189
# caralhos        0.001189
# aaugustiado     0.001189
# b...            0.001189
# hollywo...      0.001189
# rafaello1313    0.001189
# hj              0.001189
# porra           0.001189
# 237             0.001189
# melhores        0.001189
# festiv...       0.001189
# gente           0.001189
# já              0.001189
# Length: 341, dtype: float64

# %%
#Total de palavras boas
total_bom=tabela_freq_abs_bom.sum()

# %% [markdown]
# ## Tabela de frequência - Ruim

# %%
#Obtendo da tabela total os valores ruins (2)
excel_ruim=tabela_correta.loc[tabela['Classificação']==2]
excel_ruim
# Out:
#      Classificação                                             tweets
# 0                2   frckribery recebi hoje e só lembrei de certas...
# 6                2  bacurau dá de 10 x 0 em era uma vez em hollywo...
# 9                2  quanto mais leio/ouço sobre  era uma vez em   ...
# 20               2    quase dormi assistindo era uma vez em hollywood
# 31               2   josiasteofilo não consegui assistir o era uma...
# 86               2  ai eu achei era uma vez em hollywood decepcion...
# 87               2  as pessoas podiam fazer crítica de cinema tamb...
# 93               2  sobre  era uma vez em    hollywood   de tarant...
# 95               2  assisti era uma vez em hollywood ontem e que f...
# 100              2  fazia tempo que eu não via um filme tão ruim q...
# 103              2  ontem saí da sessão de era uma vez em hollywoo...
# 112              2  esse  era uma vez em    hollywood  tem 2h40  m...
# 132              2  tá  sobre oq se trata era uma vez em hollywood...
# 144              2  assisti era uma vez em hollywood e no dia segu...
# 151              2  sai de “era uma vez em hollywood” com a sensaç...
# 154              2  acho que eu assisti era uma vez em hollywood e...
# 158              2  ontem assisti era uma vez em hollywood   enten...
# 191              2  pega mal se disser que n curti  era uma vez em...
# 231              2  era uma vez em hollywood é o filme palmeiras  ...
# 242              2  era uma vez em hollywood é ruim demais  que de...
# 243              2  não assistam  era uma vez em hollywood  pq se ...
# 252              2   eleganterick to levando mt fé não depois de e...
# 258              2  não assista o filme era uma vez em hollywood d...
# 292              2   caetanobezerra eu ontem assistindo o  era uma...
# 17               2  uma hora e vinte minutos de  era uma vez em ho...
# 47               2  assisti  era uma vez em    hollywood  e achei ...
# 50               2   marxlboro era uma vez em hollywood foi o únic...
# 58               2  era uma vez em hollywood um filme bem arrastad...
# 64               2  não aguento mais a joyce falando mal de era um...
# 76               2   kmendoncafilho era uma vez em hollywood é uma...

# %% [markdown]
# #### Frequências absolutas

# %%
#transformando as informações da tabelas em strings
tabela_str_ruim = excel_ruim.tweets.to_string()
limpo_split = pd.Series(tabela_str_ruim.split())
#obtendo a frequência absoluta
tabela_freq_abs_ruim = limpo_split.value_counts()
total_ruim=tabela_freq_abs_ruim.sum()

# %% [markdown]
# #### Frequências relativa

# %%
#Obtendo tabela de frequência relativa
tabela_freq_rel_ruim = limpo_split.value_counts(True)
tabela_freq_rel_ruim
# Out:
# era               0.080645
# uma               0.077419
# em                0.074194
# vez               0.074194
# hollywood         0.051613
# de                0.029032
# não               0.019355
# e                 0.016129
# que               0.016129
# assisti           0.016129
# o                 0.016129
# eu                0.012903
# ...               0.012903
# filme             0.012903
# ontem             0.012903
# se                0.009677
# sobre             0.009677
# uma...            0.009677
# é                 0.009677
# ruim              0.006452
# e...              0.006452
# assistindo        0.006452
# achei             0.006452
# 0                 0.006452
# a                 0.006452
# um                0.006452
# mais              0.006452
# mal               0.006452
# m...              0.003226
# hollywood”        0.003226
#                     ...
# 58                0.003226
# bacurau           0.003226
# kmendoncafilho    0.003226
# 191               0.003226
# um...             0.003226
# certas...         0.003226
# 132               0.003226
# acho              0.003226
# pq                0.003226
# depois            0.003226
# tá                0.003226
# 2h40              0.003226
# decepcion...      0.003226
# n                 0.003226
# falando           0.003226
# 158               0.003226
# q...              0.003226
# 231               0.003226
# pega              0.003226
# as                0.003226
# no                0.003226
# fazer             0.003226
# consegui          0.003226
# sessão            0.003226
# 10                0.003226
# recebi            0.003226
# eleganterick      0.003226
# hollywoo...       0.003226
# to                0.003226
# 47                0.003226
# Length: 146, dtype: float64

# %% [markdown]
# ## Tabela: 0 - Irrelevantes

# %%
#Obtendo da tabela total os valores irrelevantes (0)
excel_irrelevantes=tabela_correta.loc[tabela_correta['Classificação']==0]
excel_irrelevantes
# Out:
#     Classificação                                             tweets
# 1               0  que no caso são  bacurau  era uma vez em holly...
# 2               0         eduu_miranda era uma vez gore em hollywood
# 3               0  eu quero muito assistir bacurau e era uma vez ...
# 11              0   era uma vez em hollywood  ultrapassa a marca ...
# 12              0  dá rt se hoje você   tá feliz tá animado tá an...
# 15              0  a fila tá enorme  esquece  vou ver era uma vez...
# 16              0  nao ta passando mais bacurau nao ta passando m...
# 19              0  ontem eu descobri assistindo era uma vez     e...
# 21              0  bixo  faz uns 6 meses que não vou no cinema po...
# 22              0  quem eh que vamo assisti bacurau e it  se era ...
# 23              0   luide  helioflores  pedrosazevedo era uma vez...
# 24              0  era só uma companhia pra assistir era uma vez ...
# 29              0  it  a coisa   cap 2 bacurau era uma vez em hol...
# 33              0  quem vai comigo no cinema ver era uma vez em h...
# 34              0  well  well  agora part 2 do dia no cinema  ass...
# 37              0  eu preciso assistir era uma vez em hollywood o...
# 38              0   chibnetti e eu q tenho q emendar era uma vez ...
# 39              0   reachsaravah é mais violento que “era uma vez...
# 43              0  era uma vez em hollywood  it 2 e yesterday  tr...
# 44              0   principedolacre vi não  nem vou ver então  me...
# 48              0  q historia eh essa q era uma vez em hollywood ...
# 50              0  louca é pouco para assistir era uma vez em hol...
# 51              0  quem vai cmg hj assistir era uma vez em hollyw...
# 54              0  acho que vou assistir “yesterday” hoje  ou “er...
# 56              0  no site   era uma vez em hollywood pode ganhar...
# 57              0  assisti  era uma vez rm hollywood  e você perc...
# 59              0  filmes que perdi/estou perdendo por falta de t...
# 60              0  eu reclamei que não tinha entrado era uma vez ...
# 61              0  quentin tarantino discutiu uma minissérie de  ...
# 66              0  top 10  bilheteria sabado 07 de setembro  1  i...
# ..            ...                                                ...
# 34              0  se forçar mais caga  já faz mais de um mês da ...
# 35              0  quando alguém quiser lacrar e dar a ideia de q...
# 37              0  o tal charlie dos hippies  menção  do era uma ...
# 38              0   nflnaespn acho que vc quis dizer era uma vez ...
# 39              0  ranking seleção oficial cannes 2019   1  paras...
# 41              0  vim ao shopping assistir a bacurau e era uma v...
# 42              0   kmendoncafilho  alexluizbr o cinema é lindo  ...
# 43              0        ansiosa p assistir era uma vez em hollywood
# 45              0  era uma vez em    hollywood https //t co/yemnb...
# 46              0  cena deletada de era uma vez em hollywood pode...
# 49              0   ingfcps e fizeram uma puta justiça  c vai ent...
# 51              0   102  era uma vez em    hollywood  2019  ⭐️⭐️⭐...
# 52              0  será se já tem torrent de era uma vez em holly...
# 53              0  ainda não vi era uma vez em hollywood  mas log...
# 55              0   kmendoncafilho eu fui pra ver a pré estreia d...
# 56              0  qnd eu assistir era uma vez em hollywood e bac...
# 59              0  era uma vez em hollywood vai virar série  http...
# 60              0   lustosadaniel ja assistiu “era uma vez em hol...
# 61              0  quarta feira   cine passeio = programação nova...
# 63              0  ok então estou atrasada para a semana de arqui...
# 66              0                bacurau ou era uma vez em hollywood
# 68              0   teledramaturgia essa é a cena de sharon tate ...
# 69              0  impressão minha ou era uma vez em hollywood fo...
# 72              0  era uma vez em hollywood premiere em  cannes  ...
# 73              0  na semana que saiu era um vez em hollywood eu ...
# 75              0   omalestafeito  id_error_6 a ideia é muito boa...
# 77              0  qual o ultimo filme que vc viu no cinema  — er...
# 78              0  ta passando era uma vez em hollywood aindaaa p...
# 79              0            marianahavilaa era uma vez em hollywood
# 80              0  ai queria ser só tipo a hippie bonitinha de er...
#
# [189 rows x 2 columns]

# %% [markdown]
# #### Frequências absolutas

# %%
#obtendo a frequência absoluta
limpo_split = pd.Series(tabela_str_irrelevantes.split())
tabela_freq_abs_irrelevantes = limpo_split.value_counts()
tabela_freq_abs_irrelevantes
# Out:
# uma              122
# era              121
# vez              109
# em               103
# hollywood         66
# ...               34
# de                31
# que               29
# assistir          26
# ver               24
# no                24
# e                 23
# eu                22
# a                 18
# não               17
# o                 17
# bacurau           16
# vou               14
# do                13
# cinema            13
# um                12
# é                 11
# pra               11
# e...              10
# it                 9
# quero              9
# q                  9
# 2                  9
# holly...           8
# vai                8
#                 ...
# 55                 1
# torrent            1
# oq                 1
# quis               1
# até                1
# amg                1
# utilidade          1
# passado            1
# lolaescreva        1
# drink              1
# 105                1
# rm                 1
# proje...           1
# confirmou          1
# 44                 1
# meses              1
# 282                1
# saudades           1
# louca              1
# 169                1
# caso               1
# “yesterday”        1
# com...             1
# bill               1
# 234                1
# trailer            1
# achando            1
# arapiraca          1
# 109                1
# pedrosazevedo      1
# Length: 706, dtype: int64

# %% [markdown]
# #### Frequências relativas

# %%
#Obtendo frequências relativas
tabela_freq_rel_irrelevantes = limpo_split.value_counts(True)
tabela_freq_rel_irrelevantes
# Out:
# uma              0.064584
# era              0.064055
# vez              0.057702
# em               0.054526
# hollywood        0.034939
# ...              0.017999
# de               0.016411
# que              0.015352
# assistir         0.013764
# ver              0.012705
# no               0.012705
# e                0.012176
# eu               0.011646
# a                0.009529
# não              0.008999
# o                0.008999
# bacurau          0.008470
# vou              0.007411
# do               0.006882
# cinema           0.006882
# um               0.006353
# é                0.005823
# pra              0.005823
# e...             0.005294
# it               0.004764
# quero            0.004764
# q                0.004764
# 2                0.004764
# holly...         0.004235
# vai              0.004235
#                    ...
# 55               0.000529
# torrent          0.000529
# oq               0.000529
# quis             0.000529
# até              0.000529
# amg              0.000529
# utilidade        0.000529
# passado          0.000529
# lolaescreva      0.000529
# drink            0.000529
# 105              0.000529
# rm               0.000529
# proje...         0.000529
# confirmou        0.000529
# 44               0.000529
# meses            0.000529
# 282              0.000529
# saudades         0.000529
# louca            0.000529
# 169              0.000529
# caso             0.000529
# “yesterday”      0.000529
# com...           0.000529
# bill             0.000529
# 234              0.000529
# trailer          0.000529
# achando          0.000529
# arapiraca        0.000529
# 109              0.000529
# pedrosazevedo    0.000529
# Length: 706, dtype: float64

# %% [markdown]
# ## Implementação Naive Bayes

# %%
#Realizando Laplace smoothing no código do Naive Bayes
class_relev={}
for frase1 in tabela_limpa:
    frase = frase1.split()
    log_bom = 0
    log_ruim=0
    log_irre=0
    for p in frase:
        if p in tabela_freq_rel_bom:
            log_bom += np.log10(tabela_freq_rel_bom[p])
        if p in tabela_freq_rel_ruim:
            log_ruim += np.log10(tabela_freq_rel_ruim[p])
        if p in tabela_freq_rel_irrelevantes:
            log_irre += np.log10(tabela_freq_rel_irrelevantes[p])
    log_bom*=-1
    log_ruim*=-1
    log_irre*=-1
    if log_bom > log_ruim and log_bom > log_irre:
        class_relev[frase1]=1
    elif log_ruim > log_bom and log_ruim > log_irre:
        class_relev[frase1]=2
    else:
        class_relev[frase1]=0


class_relevt = pd.DataFrame.from_dict(class_relev,orient='index')
class_relevt

tabela_correta

naive=[]
for i in class_relevt[0]:
    naive.append(i)
naive

tabela_correta["naive"]=naive    
classificacao=[]
for i in tabela_correta.Classificação:
    classificacao.append(i)

#Classificando nossos resultados como: Verdadeiro Irrelevante, Falso Positivo, Falso Negativo, Verdadeiro Positivo, 
#Falso Irrelevante, Falso Negativo, Verdadeiro Negativo, Falso Irrelevante e Falso Positivo.
tipo=[0]*301
i=0
for numero in classificacao:
    if numero==naive[i] and numero==0:
        tipo[i]="Verdadeiro Irrelevante"
        
    elif numero!=naive[i] and numero==0:
        if  numero!=naive[i] and naive[i]==1:
            tipo[i]="Falso Positivo"
        elif numero!=naive[i] and naive[i]==2:
            tipo[i]= 'Falso Negativo'
            
    elif numero==naive[i] and numero==1:
            tipo[i]="Verdadeiro Positivo"
        
    elif numero!=naive[i] and numero==1:
        if naive[i]==0:
            tipo[i]="Falso Irrelevante"
        elif naive[i]==2:
            tipo[i]="Falso Negativo"
        
    elif numero==naive[i] and numero==2:
        tipo[i]="Verdadeiro Negativo"
        
    elif numero!=naive[i] and numero==2:
        if naive[i]==0:
            tipo[i]="Falso Irrelevante"
        elif naive[i]==1:
            tipo[i]="Falso Positivo"
    i+=1



tabela_correta["Tipo"]=tipo  
tabela_correta
# Out:
#     Classificação                                             tweets  naive  \
# 0               2   frckribery recebi hoje e só lembrei de certas...      0
# 1               0  que no caso são  bacurau  era uma vez em holly...      0
# 2               0         eduu_miranda era uma vez gore em hollywood      0
# 3               0  eu quero muito assistir bacurau e era uma vez ...      1
# 5               1  vai sair uma versão de 4 horas de era uma vez ...      1
# 6               2  bacurau dá de 10 x 0 em era uma vez em hollywo...      0
# 9               2  quanto mais leio/ouço sobre  era uma vez em   ...      2
# 10              1  boa noite seguidores  hoje a crítica vai para ...      1
# 11              0   era uma vez em hollywood  ultrapassa a marca ...      0
# 12              0  dá rt se hoje você   tá feliz tá animado tá an...      0
# 15              0  a fila tá enorme  esquece  vou ver era uma vez...      0
# 16              0  nao ta passando mais bacurau nao ta passando m...      0
# 17              1  eu só queria registrar que vi era uma vez em h...      1
# 19              0  ontem eu descobri assistindo era uma vez     e...      0
# 20              2    quase dormi assistindo era uma vez em hollywood      2
# 21              0  bixo  faz uns 6 meses que não vou no cinema po...      0
# 22              0  quem eh que vamo assisti bacurau e it  se era ...      0
# 23              0   luide  helioflores  pedrosazevedo era uma vez...      0
# 24              0  era só uma companhia pra assistir era uma vez ...      0
# 26              1  era uma vez em hollywood é muito bom gente pra...      0
# 27              1  assisti  era uma vez em hollywood    e ainda e...      0
# 29              0  it  a coisa   cap 2 bacurau era uma vez em hol...      0
# 30              1  era uma vez em    hollywood é um puta filme do...      0
# 31              2   josiasteofilo não consegui assistir o era uma...      0
# 33              0  quem vai comigo no cinema ver era uma vez em h...      0
# 34              0  well  well  agora part 2 do dia no cinema  ass...      0
# 36              1  era uma vez em hollywood = dahora cena final s...      1
# 37              0  eu preciso assistir era uma vez em hollywood o...      0
# 38              0   chibnetti e eu q tenho q emendar era uma vez ...      0
# 39              0   reachsaravah é mais violento que “era uma vez...      0
# ..            ...                                                ...    ...
# 51              0   102  era uma vez em    hollywood  2019  ⭐️⭐️⭐...      0
# 52              0  será se já tem torrent de era uma vez em holly...      0
# 53              0  ainda não vi era uma vez em hollywood  mas log...      0
# 54              1   kmendoncafilho achei bacurau melhor e era uma...      0
# 55              0   kmendoncafilho eu fui pra ver a pré estreia d...      0
# 56              0  qnd eu assistir era uma vez em hollywood e bac...      0
# 57              1   carlos_history  misterpinkeyes  kmendoncafilh...      1
# 58              2  era uma vez em hollywood um filme bem arrastad...      1
# 59              0  era uma vez em hollywood vai virar série  http...      0
# 60              0   lustosadaniel ja assistiu “era uma vez em hol...      0
# 61              0  quarta feira   cine passeio = programação nova...      0
# 62              1  era uma vez em hollywood bom d  tarantino já f...      1
# 63              0  ok então estou atrasada para a semana de arqui...      0
# 64              2  não aguento mais a joyce falando mal de era um...      0
# 65              1  o final de “era uma vez em    hollywood” me em...      1
# 66              0                bacurau ou era uma vez em hollywood      0
# 67              1   davidbowiezinho ai eu ainda não vi bacurau e ...      0
# 68              0   teledramaturgia essa é a cena de sharon tate ...      0
# 69              0  impressão minha ou era uma vez em hollywood fo...      0
# 70              1  bacurau  é um puta filmaço era uma vez em holl...      1
# 71              1  o que você achou de era uma vez em hollywood —...      0
# 72              0  era uma vez em hollywood premiere em  cannes  ...      0
# 73              0  na semana que saiu era um vez em hollywood eu ...      0
# 74              1   renatoaogimenes viu o era uma vez em hollywoo...      1
# 75              0   omalestafeito  id_error_6 a ideia é muito boa...      0
# 76              2   kmendoncafilho era uma vez em hollywood é uma...      0
# 77              0  qual o ultimo filme que vc viu no cinema  — er...      0
# 78              0  ta passando era uma vez em hollywood aindaaa p...      0
# 79              0            marianahavilaa era uma vez em hollywood      0
# 80              0  ai queria ser só tipo a hippie bonitinha de er...      0
#
#                       Tipo
# 0        Falso Irrelevante
# 1   Verdadeiro Irrelevante
# 2   Verdadeiro Irrelevante
# 3           Falso Positivo
# 5      Verdadeiro Positivo
# 6        Falso Irrelevante
# 9      Verdadeiro Negativo
# 10     Verdadeiro Positivo
# 11  Verdadeiro Irrelevante
# 12  Verdadeiro Irrelevante
# 15  Verdadeiro Irrelevante
# 16  Verdadeiro Irrelevante
# 17     Verdadeiro Positivo
# 19  Verdadeiro Irrelevante
# 20     Verdadeiro Negativo
# 21  Verdadeiro Irrelevante
# 22  Verdadeiro Irrelevante
# 23  Verdadeiro Irrelevante
# 24  Verdadeiro Irrelevante
# 26       Falso Irrelevante
# 27       Falso Irrelevante
# 29  Verdadeiro Irrelevante
# 30       Falso Irrelevante
# 31       Falso Irrelevante
# 33  Verdadeiro Irrelevante
# 34  Verdadeiro Irrelevante
# 36     Verdadeiro Positivo
# 37  Verdadeiro Irrelevante
# 38  Verdadeiro Irrelevante
# 39  Verdadeiro Irrelevante
# ..                     ...
# 51  Verdadeiro Irrelevante
# 52  Verdadeiro Irrelevante
# 53  Verdadeiro Irrelevante
# 54       Falso Irrelevante
# 55  Verdadeiro Irrelevante
# 56  Verdadeiro Irrelevante
# 57     Verdadeiro Positivo
# 58          Falso Positivo
# 59  Verdadeiro Irrelevante
# 60  Verdadeiro Irrelevante
# 61  Verdadeiro Irrelevante
# 62     Verdadeiro Positivo
# 63  Verdadeiro Irrelevante
# 64       Falso Irrelevante
# 65     Verdadeiro Positivo
# 66  Verdadeiro Irrelevante
# 67       Falso Irrelevante
# 68  Verdadeiro Irrelevante
# 69  Verdadeiro Irrelevante
# 70     Verdadeiro Positivo
# 71       Falso Irrelevante
# 72  Verdadeiro Irrelevante
# 73  Verdadeiro Irrelevante
# 74     Verdadeiro Positivo
# 75  Verdadeiro Irrelevante
# 76       Falso Irrelevante
# 77  Verdadeiro Irrelevante
# 78  Verdadeiro Irrelevante
# 79  Verdadeiro Irrelevante
# 80  Verdadeiro Irrelevante
#
# [301 rows x 4 columns]

# %%
#Valores da frequência relativa da tabela concreta para realizar comparações
print(tabela_correta["Classificação"].value_counts(normalize=True)*100)
# Out:
# 0    62.790698
# 1    27.242525
# 2     9.966777
# Name: Classificação, dtype: float64

# %%
#Teste de qualidade do nosso classificador
#Porcentagens de nossas classificações
print(tabela_correta["Tipo"].value_counts(normalize=True)*100)
# Out:
# Verdadeiro Irrelevante    60.797342
# Falso Irrelevante         19.269103
# Verdadeiro Positivo       15.614618
# Falso Positivo             2.990033
# Verdadeiro Negativo        1.328904
# Name: Tipo, dtype: float64

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Após usar o classificador Naive Bayes para diversos tweets da tabela Teste sobre "Era uma vez em Hollywood", novo filme do diretor Quentin Tarantino, foi possível observar uma porcentagem considerável de erros, que consistem em Falsos Irrelevantes (19.27%) e Falsos Positivos(2.99%), representando 22,25% do total. Isso ocorreu principalmente devido ao fato de que foi selecionado uma quantidade de tweets em que ocorria frequentimente a repetição de palavras, limitando a base de dados do classificador. É interessante observar que não obtivemos nenhum Falso Negativo, provavelmente, pela pequena quantidade de tweets "ruins". Porém, mesmo com esses erros, o classificador apresenta uma acurácia de 77,74%, consideravelmente alta. O maior índice de acertos está relacionado aos Verdadeiros irrelevantes, fato que ocorreu porque a maioria dos tweets nas bases de treinamento e teste de dados foram classificados como irrelevantes, aumentando sua probabilidade. Isso se dá graças ao grande número de usuários que estavam comentando a respeito do filme sem  ter o assistido.
#
#    Ao classificar manualmente os tweets que possuíam dupla negação ou sarcasmo, foi levado em consideração a conotação que eles sugeriam. Porém, a maioria era sobre a duração do filme, ou que ele era de difícil compreensão. Por isso, a maioria desses tweets foram classificados como de cunho negativo, e, como  o nosso classificador é um reflexo da classificação manual, a maior probabilidade é que um tweet com essas características seja classificado como Negativo.
#
#    O nosso projeto deve continuar a ser financiado porque ele apresentou uma boa quantidade de acertos, mesmo utilizando uma pequena base de dados. Além disso, ele ajudará a empresa a ter um monitoramento dessa rede social de forma mais automatizada, sem que um funcionário precise ficar analisando cada tweet.Ainda, ele pode ficar melhor estruturado, tendo seu algoritmo executado em diferentes máquinas para aumentar a velocidade de classificação, como sugerido no site "https://machinelearningmastery.com/better-naive-bayes/"; além de um aumento na sua base de dados e categorias de classificação. Um exemplo seria utilizar uma ferramenta de monitoramento periódico, e, tornar a mensagem mais perceptível na time-line, caso for boa, ou chamando a atenção da equipe de Marketing, se for depreciativa.
#
#    O motivo pelo qual a base de treinamento não pode ser realimentada automaticamente utilizando o classificador, é que já existe um percentual de erro na classificação do banco de dados do sistema, e, ao colocar um novo tweet, ele pode sofrer essa influencia e ser classificado erroneamente também, alimentando a base de dados com um erro, e, portanto, prejudicando a eficácia do classificador.
